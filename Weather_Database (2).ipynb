# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(54.85110426470965, 85.91530270114583), (-67.52764585373333, -171.11968076004942), (-37.12787250223494, 17.771815659435077), (34.40329316837689, -44.94110356825374), (-58.3691012204931, 29.966378702596472), (20.52794656646431, 59.985699435739065), (41.31039540449041, -22.163690203098867), (-55.89859793427163, -105.44063021368339), (34.0941606831185, -5.924455454012275), (58.19838892392997, 77.77186929368168), (49.99841612073163, 11.780919080050609), (-2.9419632833226075, 104.72414997547736), (75.7028483828854, 152.71468857013906), (-49.64030182378681, -151.48336729625407), (1.814392158956636, -134.48962025628884), (39.69808745088301, -22.586444363418877), (12.287754827190966, -68.76453642648852), (41.99168938706222, -118.52008064301198), (0.8566805258806198, 9.2164081579254), (28.777706655438266, 123.95774212114924), (-70.05549546042488, 42.45536946176219), (64.82745165468202, 155.89896216189896), (73.8202849404513, 68.3731537623089), (24.227551383083068, -110.70617937585605), (27.156774862812483, -3.0784454128435925), (-69.3822925460058, -167.63674414347273), (39.905307481991116, 112.42756067683462), (82.63033369756815, -89.32571511651926), (34.89146340426912, 33.198644493789146), (-3.560116761474305, 149.01199223123598), (38.37903836502147, -98.87964191244058), (-71.81245160487111, -63.1806852486674), (-36.90485736283792, -26.836092136418074), (58.6285727766946, 118.53191480911488), (28.32147019620058, -100.863510853162), (-85.14865763307586, -121.28432596249954), (45.439725600283424, -145.07154122188578), (-28.563827588666086, 14.77730063094603), (1.9496307668213575, 32.19702641518302), (66.438512364068, 123.47609458962847), (79.03903010192784, 166.82945183380127), (6.538698555031004, -59.881763751410844), (-35.43366800016852, -156.4887735578251), (63.33347159677834, 177.58391076657352), (-59.55402782837453, 0.5186584725225032), (-8.031886007170883, -27.773012664588435), (34.33994901713105, -157.9633413242011), (-55.5018842392906, 59.405920095377866), (18.979842072793645, -31.19188503045399), (81.41801637286503, -99.8888126351803), (-70.83194088919151, 165.2075272550697), (-34.916148309160995, -31.864096312053164), (68.6887467411816, -152.39051436543855), (23.320869505499303, 98.88583117670157), (35.196443770087114, 112.14791247503109), (28.189252749279106, -9.87781570459947), (74.8334819676966, 67.99613603842727), (-10.53561270375306, 95.21305155964916), (19.47322093566102, 33.06670182973903), (-16.73329519076428, -55.95996475119503), (-54.31217340768874, 22.71762004477867), (77.59257554639427, 106.62094226778083), (49.69201466345197, -55.83788263868655), (75.00736294618613, 149.09090537280292), (-30.147706013469083, 62.39559676395024), (25.341500075784026, -72.38882275084006), (-53.33647765118234, -44.156651724651596), (-43.660464960923775, 8.749436853931059), (15.682802644484013, 71.60488067578532), (-84.63297014883537, -89.41121320177737), (-61.77147602285907, -137.72945707973165), (-77.64246092661031, -153.02022934527773), (-41.19851065421621, -51.50243981964417), (-9.337883189639456, 72.37953184342854), (-24.345346888539865, -148.3314298115164), (-87.11472837595718, -137.6474720515808), (58.923581519000095, 138.43922889351325), (-4.270594643015869, 18.667270456964786), (-40.80251950156872, -10.514702372455815), (51.93016651276477, 21.4478612023006), (83.7469799229421, 68.31857656602429), (74.98000186339593, 148.8462373340222), (-68.33221162262012, -136.54323615386346), (47.49705296243437, -14.831950044458466), (33.08857800863662, -90.63002331882987), (-39.33980139339463, 115.98190221588453), (53.00338206389182, -140.60499775992827), (-66.06706851969798, 42.072333371742616), (61.84011747651229, 110.333438268632), (84.6692342917328, -139.20726026004957), (24.179733040976444, -157.2975478661054), (20.093138549263983, -84.73409757474091), (57.26859401607922, 37.08866125546939), (89.06329457398627, -19.027412973806776), (70.6790909555099, 94.49832158405758), (77.47631386317485, -63.37331862468166), (10.285288332645791, -1 ...

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
#import requests library
import requests

#import api
from config import g_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+g_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1c667cec7ddebf8bbcce30902d1e1d0

# %%
##Import the datetime module from the datetime library
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
        # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

        # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
        # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']

        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

         # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                        "Country": city_country,
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Current Description":description })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | plotnikovo
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | torbay
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | sur
# Processing Record 7 of Set 1 | vila franca do campo
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | sidi qasim
# City not found. Skipping...
# Processing Record 10 of Set 1 | kedrovyy
# Processing Record 11 of Set 1 | munchberg
# Processing Record 12 of Set 1 | palembang
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | willemstad
# Processing Record 17 of Set 1 | winnemucca
# Processing Record 18 of Set 1 | cocobeach
# Processing Record 19 of Set 1 | shenjiamen
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | omsukchan
# Processing Record 22 of Set 1 | aksarka
# Processing Record 23 of Set 1 | la paz
# Processing Record 24 of Set 1 | adrar
# Processing Record 25 of Set 1 | datong
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | lemesos
# City not found. Skipping...
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | great bend
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | chara
# Processing Record 33 of Set 1 | allende
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | oranjemund
# Processing Record 37 of Set 1 | apac
# Processing Record 38 of Set 1 | zhigansk
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | bartica
# Processing Record 41 of Set 1 | anadyr
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | pitimbu
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | ponta do sol
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | lashio
# Processing Record 1 of Set 2 | yima
# Processing Record 2 of Set 2 | tiznit
# Processing Record 3 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 2 | bengkulu
# Processing Record 5 of Set 2 | marawi
# Processing Record 6 of Set 2 | barao de melgaco
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | springdale
# Processing Record 10 of Set 2 | souillac
# Processing Record 11 of Set 2 | cockburn town
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | solnechnyy
# Processing Record 17 of Set 2 | bulungu
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | garwolin
# Processing Record 20 of Set 2 | dingle
# Processing Record 21 of Set 2 | yazoo city
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | yerbogachen
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | wahiawa
# Processing Record 27 of Set 2 | guane
# Processing Record 28 of Set 2 | kesova gora
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | khuzdar
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | vao
# Processing Record 36 of Set 2 | maniitsoq
# Processing Record 37 of Set 2 | aloleng
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 41 of Set 2 | iskateley
# Processing Record 42 of Set 2 | te anau
# Processing Record 43 of Set 2 | avera
# Processing Record 44 of Set 2 | kuytun
# Processing Record 45 of Set 2 | mpika
# Processing Record 46 of Set 2 | saint anthony
# Processing Record 47 of Set 2 | suao
# City not found. Skipping...
# Processing Record 48 of Set 2 | annau
# Processing Record 49 of Set 2 | boden
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | severo-kurilsk
# Processing Record 2 of Set 3 | codrington
# Processing Record 3 of Set 3 | estelle
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | shache
# Processing Record 6 of Set 3 | namatanai
# Processing Record 7 of Set 3 | novyy urgal
# Processing Record 8 of Set 3 | cayenne
# Processing Record 9 of Set 3 | shangzhi
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | cap malheureux
# Processing Record 13 of Set 3 | lebu
# Processing Record 14 of Set 3 | victoria
# Processing Record 15 of Set 3 | maryborough
# Processing Record 16 of Set 3 | carutapera
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | taree
# Processing Record 19 of Set 3 | noyabrsk
# Processing Record 20 of Set 3 | asau
# Processing Record 21 of Set 3 | sechura
# Processing Record 22 of Set 3 | busselton
# Processing Record 23 of Set 3 | pervomayskiy
# Processing Record 24 of Set 3 | fortuna
# Processing Record 25 of Set 3 | taoudenni
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | upata
# Processing Record 28 of Set 3 | yumen
# Processing Record 29 of Set 3 | guerrero negro
# Processing Record 30 of Set 3 | mananara
# Processing Record 31 of Set 3 | arona
# Processing Record 32 of Set 3 | flin flon
# Processing Record 33 of Set 3 | poum
# Processing Record 34 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 3 | sandwick
# Processing Record 36 of Set 3 | bethel
# Processing Record 37 of Set 3 | griffith
# Processing Record 38 of Set 3 | vitim
# Processing Record 39 of Set 3 | hermiston
# Processing Record 40 of Set 3 | kirakira
# Processing Record 41 of Set 3 | gladstone
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | esperance
# Processing Record 44 of Set 3 | ancud
# Processing Record 45 of Set 3 | barahona
# Processing Record 46 of Set 3 | norman wells
# Processing Record 47 of Set 3 | ucluelet
# Processing Record 48 of Set 3 | nanortalik
# Processing Record 49 of Set 3 | cherskiy
# Processing Record 50 of Set 3 | faya
# Processing Record 1 of Set 4 | santa clara
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | sao filipe
# Processing Record 4 of Set 4 | port hardy
# Processing Record 5 of Set 4 | san quintin
# Processing Record 6 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 4 | longyearbyen
# Processing Record 8 of Set 4 | caravelas
# Processing Record 9 of Set 4 | elizabeth city
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | sobolevo
# Processing Record 13 of Set 4 | maldonado
# Processing Record 14 of Set 4 | price
# Processing Record 15 of Set 4 | saldanha
# Processing Record 16 of Set 4 | burica
# City not found. Skipping...
# Processing Record 17 of Set 4 | tomatlan
# Processing Record 18 of Set 4 | new norfolk
# Processing Record 19 of Set 4 | ulladulla
# Processing Record 20 of Set 4 | butaritari
# Processing Record 21 of Set 4 | hualmay
# Processing Record 22 of Set 4 | upernavik
# Processing Record 23 of Set 4 | huarmey
# Processing Record 24 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 4 | sosnovo-ozerskoye
# Processing Record 26 of Set 4 | chokwe
# Processing Record 27 of Set 4 | kovdor
# Processing Record 28 of Set 4 | saint-philippe
# Processing Record 29 of Set 4 | san andres
# Processing Record 30 of Set 4 | qaqortoq
# Processing Record 31 of Set 4 | goure
# Processing Record 32 of Set 4 | riberalta
# Processing Record 33 of Set 4 | muana
# Processing Record 34 of Set 4 | bathsheba
# Processing Record 35 of Set 4 | chuncheng
# Processing Record 36 of Set 4 | okhotsk
# Processing Record 37 of Set 4 | dzhebariki-khaya
# Processing Record 38 of Set 4 | tasiilaq
# Processing Record 39 of Set 4 | shingu
# Processing Record 40 of Set 4 | avarua
# Processing Record 41 of Set 4 | borogontsy
# Processing Record 42 of Set 4 | comodoro rivadavia
# Processing Record 43 of Set 4 | rampura
# Processing Record 44 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 4 | dingtao
# Processing Record 46 of Set 4 | wencheng
# Processing Record 47 of Set 4 | savannah bight
# Processing Record 48 of Set 4 | mikhaylovka
# Processing Record 49 of Set 4 | klaksvik
# Processing Record 50 of Set 4 | kudahuvadhoo
# Processing Record 1 of Set 5 | kutum
# Processing Record 2 of Set 5 | neiafu
# Processing Record 3 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 5 | mabaruma
# Processing Record 5 of Set 5 | kajaani
# Processing Record 6 of Set 5 | clyde river
# Processing Record 7 of Set 5 | sisimiut
# Processing Record 8 of Set 5 | nikolskoye
# Processing Record 9 of Set 5 | katima mulilo
# Processing Record 10 of Set 5 | rio grande
# Processing Record 11 of Set 5 | brainerd
# Processing Record 12 of Set 5 | ahipara
# Processing Record 13 of Set 5 | georgetown
# Processing Record 14 of Set 5 | emborion
# Processing Record 15 of Set 5 | isangel
# Processing Record 16 of Set 5 | arkhangelskaya
# Processing Record 17 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 5 | deputatskiy
# Processing Record 19 of Set 5 | nova olimpia
# Processing Record 20 of Set 5 | leningradskiy
# Processing Record 21 of Set 5 | auki
# Processing Record 22 of Set 5 | vaovai
# City not found. Skipping...
# Processing Record 23 of Set 5 | fort-shevchenko
# Processing Record 24 of Set 5 | manta
# Processing Record 25 of Set 5 | buraydah
# Processing Record 26 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 5 | kruisfontein
# Processing Record 28 of Set 5 | saint-pierre
# Processing Record 29 of Set 5 | pangnirtung
# Processing Record 30 of Set 5 | dunedin
# Processing Record 31 of Set 5 | ludvika
# Processing Record 32 of Set 5 | olinda
# Processing Record 33 of Set 5 | kurush
# Processing Record 34 of Set 5 | langham
# Processing Record 35 of Set 5 | lompoc
# Processing Record 36 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 5 | jardim
# Processing Record 38 of Set 5 | portland
# Processing Record 39 of Set 5 | filingue
# Processing Record 40 of Set 5 | marzuq
# Processing Record 41 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 5 | koroni
# Processing Record 43 of Set 5 | mildura
# Processing Record 44 of Set 5 | san patricio
# Processing Record 45 of Set 5 | genhe
# Processing Record 46 of Set 5 | saint george
# Processing Record 47 of Set 5 | minab
# Processing Record 48 of Set 5 | sakata
# Processing Record 49 of Set 5 | beringovskiy
# Processing Record 50 of Set 5 | nome
# Processing Record 1 of Set 6 | mount gambier
# Processing Record 2 of Set 6 | puri
# Processing Record 3 of Set 6 | coihaique
# Processing Record 4 of Set 6 | necochea
# Processing Record 5 of Set 6 | geraldton
# Processing Record 6 of Set 6 | toppenish
# Processing Record 7 of Set 6 | itaituba
# Processing Record 8 of Set 6 | zapolyarnyy
# Processing Record 9 of Set 6 | pafos
# Processing Record 10 of Set 6 | nuuk
# Processing Record 11 of Set 6 | kousseri
# Processing Record 12 of Set 6 | makokou
# Processing Record 13 of Set 6 | rafaela
# Processing Record 14 of Set 6 | kolpashevo
# Processing Record 15 of Set 6 | grand gaube
# Processing Record 16 of Set 6 | vostok
# Processing Record 17 of Set 6 | warren
# Processing Record 18 of Set 6 | kismayo
# Processing Record 19 of Set 6 | pisco
# Processing Record 20 of Set 6 | mayumba
# Processing Record 21 of Set 6 | berdigestyakh
# Processing Record 22 of Set 6 | buriti dos lopes
# Processing Record 23 of Set 6 | thohoyandou
# Processing Record 24 of Set 6 | bowen
# Processing Record 25 of Set 6 | hofn
# Processing Record 26 of Set 6 | maceio
# Processing Record 27 of Set 6 | tacuarembo
# Processing Record 28 of Set 6 | kaitangata
# Processing Record 29 of Set 6 | kasama
# Processing Record 30 of Set 6 | albert
# Processing Record 31 of Set 6 | daru
# Processing Record 32 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 6 | pauini
# Processing Record 34 of Set 6 | kloulklubed
# Processing Record 35 of Set 6 | businga
# Processing Record 36 of Set 6 | marfino
# Processing Record 37 of Set 6 | puerto del rosario
# Processing Record 38 of Set 6 | pacific grove
# Processing Record 39 of Set 6 | ambilobe
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | svecha
# Processing Record 42 of Set 6 | tilichiki
# Processing Record 43 of Set 6 | itarema
# Processing Record 44 of Set 6 | lasa
# Processing Record 45 of Set 6 | aras
# Processing Record 46 of Set 6 | imbituba
# Processing Record 47 of Set 6 | athabasca
# Processing Record 48 of Set 6 | odweyne
# Processing Record 49 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 6 | hobart
# Processing Record 1 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 7 | kahului
# Processing Record 4 of Set 7 | hirara
# Processing Record 5 of Set 7 | serik
# Processing Record 6 of Set 7 | maroua
# Processing Record 7 of Set 7 | sao joaquim
# Processing Record 8 of Set 7 | lurgan
# Processing Record 9 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 7 | prieska
# Processing Record 12 of Set 7 | iqaluit
# Processing Record 13 of Set 7 | valdivia
# Processing Record 14 of Set 7 | chumikan
# Processing Record 15 of Set 7 | rindal
# Processing Record 16 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 7 | atbasar
# Processing Record 18 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 7 | dingzhou
# Processing Record 20 of Set 7 | abu kamal
# Processing Record 21 of Set 7 | trairi
# Processing Record 22 of Set 7 | miles city
# Processing Record 23 of Set 7 | ilulissat
# Processing Record 24 of Set 7 | sola
# Processing Record 25 of Set 7 | goderich
# Processing Record 26 of Set 7 | nizhniy kuranakh
# Processing Record 27 of Set 7 | along
# Processing Record 28 of Set 7 | riverton
# Processing Record 29 of Set 7 | quetzaltepec
# City not found. Skipping...
# Processing Record 30 of Set 7 | de-kastri
# Processing Record 31 of Set 7 | kasempa
# Processing Record 32 of Set 7 | galesong
# Processing Record 33 of Set 7 | acarau
# Processing Record 34 of Set 7 | cabo san lucas
# Processing Record 35 of Set 7 | dolinsk
# Processing Record 36 of Set 7 | laguna
# Processing Record 37 of Set 7 | fuyu
# Processing Record 38 of Set 7 | katsuura
# Processing Record 39 of Set 7 | ribeira grande
# Processing Record 40 of Set 7 | chuy
# Processing Record 41 of Set 7 | vitre
# Processing Record 42 of Set 7 | gornopravdinsk
# Processing Record 43 of Set 7 | boa vista
# Processing Record 44 of Set 7 | san angelo
# Processing Record 45 of Set 7 | lavrentiya
# Processing Record 46 of Set 7 | kununurra
# Processing Record 47 of Set 7 | airai
# Processing Record 48 of Set 7 | kota belud
# Processing Record 49 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 7 | bentong
# Processing Record 1 of Set 8 | rtishchevo
# Processing Record 2 of Set 8 | cherbourg
# Processing Record 3 of Set 8 | husavik
# Processing Record 4 of Set 8 | acapulco
# Processing Record 5 of Set 8 | dukat
# Processing Record 6 of Set 8 | port lincoln
# Processing Record 7 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 8 | alice springs
# Processing Record 9 of Set 8 | jiwani
# Processing Record 10 of Set 8 | bandundu
# Processing Record 11 of Set 8 | boca do acre
# Processing Record 12 of Set 8 | kulhudhuffushi
# Processing Record 13 of Set 8 | bud
# Processing Record 14 of Set 8 | padang
# Processing Record 15 of Set 8 | zabol
# Processing Record 16 of Set 8 | kahama
# Processing Record 17 of Set 8 | masuguru
# Processing Record 18 of Set 8 | san cristobal
# Processing Record 19 of Set 8 | panacan
# Processing Record 20 of Set 8 | poso
# Processing Record 21 of Set 8 | sterlibashevo
# Processing Record 22 of Set 8 | amasya
# Processing Record 23 of Set 8 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 24 of Set 8 | murud
# Processing Record 25 of Set 8 | juneau
# Processing Record 26 of Set 8 | nola
# Processing Record 27 of Set 8 | poronaysk
# Processing Record 28 of Set 8 | namibe
# Processing Record 29 of Set 8 | kenai
# Processing Record 30 of Set 8 | morgan city
# Processing Record 31 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 8 | tessalit
# Processing Record 33 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 8 | mandalgovi
# Processing Record 35 of Set 8 | gayeri
# Processing Record 36 of Set 8 | saryg-sep
# Processing Record 37 of Set 8 | vallenar
# Processing Record 38 of Set 8 | pakaur
# Processing Record 39 of Set 8 | inuvik
# Processing Record 40 of Set 8 | great falls
# Processing Record 41 of Set 8 | ostrovnoy
# Processing Record 42 of Set 8 | terebovlya
# Processing Record 43 of Set 8 | kampene
# Processing Record 44 of Set 8 | kavaratti
# Processing Record 45 of Set 8 | vila
# Processing Record 46 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 47 of Set 8 | port blair
# Processing Record 48 of Set 8 | capelinha
# Processing Record 49 of Set 8 | dzaoudzi
# Processing Record 50 of Set 8 | camocim
# Processing Record 1 of Set 9 | singaraja
# Processing Record 2 of Set 9 | suifenhe
# Processing Record 3 of Set 9 | terney
# Processing Record 4 of Set 9 | lujan
# Processing Record 5 of Set 9 | fohnsdorf
# Processing Record 6 of Set 9 | galle
# Processing Record 7 of Set 9 | turukhansk
# Processing Record 8 of Set 9 | arcata
# Processing Record 9 of Set 9 | jinchang
# Processing Record 10 of Set 9 | barcelos
# Processing Record 11 of Set 9 | chiredzi
# Processing Record 12 of Set 9 | sorland
# Processing Record 13 of Set 9 | xiongshi
# City not found. Skipping...
# Processing Record 14 of Set 9 | provins
# Processing Record 15 of Set 9 | freeport
# Processing Record 16 of Set 9 | bay roberts
# Processing Record 17 of Set 9 | port-gentil
# Processing Record 18 of Set 9 | alofi
# Processing Record 19 of Set 9 | ayia anna
# Processing Record 20 of Set 9 | mariveles
# Processing Record 21 of Set 9 | hennenman
# Processing Record 22 of Set 9 | zile
# Processing Record 23 of Set 9 | howard springs
# Processing Record 24 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 9 | ratnagiri
# Processing Record 26 of Set 9 | rassvet
# Processing Record 27 of Set 9 | port macquarie
# Processing Record 28 of Set 9 | abu dhabi
# Processing Record 29 of Set 9 | general roca
# Processing Record 30 of Set 9 | zhanaozen
# Processing Record 31 of Set 9 | chapais
# Processing Record 32 of Set 9 | faenza
# Processing Record 33 of Set 9 | pangai
# Processing Record 34 of Set 9 | kapoeta
# Processing Record 35 of Set 9 | mount isa
# Processing Record 36 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 37 of Set 9 | izumo
# Processing Record 38 of Set 9 | zonguldak
# Processing Record 39 of Set 9 | aklavik
# Processing Record 40 of Set 9 | dongsheng
# Processing Record 41 of Set 9 | manicore
# Processing Record 42 of Set 9 | aykhal
# Processing Record 43 of Set 9 | karaton
# Processing Record 44 of Set 9 | dvinskoy
# Processing Record 45 of Set 9 | luocheng
# Processing Record 46 of Set 9 | sokoni
# Processing Record 47 of Set 9 | vardo
# Processing Record 48 of Set 9 | butembo
# Processing Record 49 of Set 9 | umm lajj
# Processing Record 50 of Set 9 | sedniv
# Processing Record 1 of Set 10 | ulaanbaatar
# Processing Record 2 of Set 10 | sorong
# Processing Record 3 of Set 10 | labuhan
# Processing Record 4 of Set 10 | kangaatsiaq
# Processing Record 5 of Set 10 | kant
# Processing Record 6 of Set 10 | kindu
# Processing Record 7 of Set 10 | la palma
# Processing Record 8 of Set 10 | veraval
# Processing Record 9 of Set 10 | santa teresa
# Processing Record 10 of Set 10 | honiara
# Processing Record 11 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 12 of Set 10 | kiama
# Processing Record 13 of Set 10 | lahaina
# Processing Record 14 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 10 | bubaque
# Processing Record 16 of Set 10 | irbil
# Processing Record 17 of Set 10 | grahamstown
# Processing Record 18 of Set 10 | natalinsk
# Processing Record 19 of Set 10 | nantucket
# Processing Record 20 of Set 10 | rudbar
# Processing Record 21 of Set 10 | ranot
# Processing Record 22 of Set 10 | zavetnoye
# Processing Record 23 of Set 10 | cabedelo
# Processing Record 24 of Set 10 | wenling
# Processing Record 25 of Set 10 | axim
# Processing Record 26 of Set 10 | clonakilty
# Processing Record 27 of Set 10 | cravo norte
# Processing Record 28 of Set 10 | pochutla
# Processing Record 29 of Set 10 | karratha
# Processing Record 30 of Set 10 | halifax
# Processing Record 31 of Set 10 | angostura
# Processing Record 32 of Set 10 | fairbanks
# Processing Record 33 of Set 10 | bilma
# Processing Record 34 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 10 | sinnamary
# Processing Record 36 of Set 10 | kilmez
# City not found. Skipping...
# Processing Record 37 of Set 10 | constitucion
# Processing Record 38 of Set 10 | hamilton
# Processing Record 39 of Set 10 | houston
# Processing Record 40 of Set 10 | merauke
# Processing Record 41 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 10 | belyy yar
# Processing Record 43 of Set 10 | port moresby
# Processing Record 44 of Set 10 | warrnambool
# Processing Record 45 of Set 10 | coquimbo
# Processing Record 46 of Set 10 | san vicente
# Processing Record 47 of Set 10 | uaua
# Processing Record 48 of Set 10 | bhan
# Processing Record 49 of Set 10 | nenjiang
# Processing Record 50 of Set 10 | andenes
# Processing Record 1 of Set 11 | nawa
# Processing Record 2 of Set 11 | paita
# Processing Record 3 of Set 11 | luderitz
# Processing Record 4 of Set 11 | san jose de guanipa
# Processing Record 5 of Set 11 | the valley
# Processing Record 6 of Set 11 | porto novo
# Processing Record 7 of Set 11 | three hills
# Processing Record 8 of Set 11 | kropotkin
# Processing Record 9 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 11 | baker city
# Processing Record 11 of Set 11 | geneva
# Processing Record 12 of Set 11 | lorengau
# Processing Record 13 of Set 11 | galbshtadt
# Processing Record 14 of Set 11 | mahanoro
# Processing Record 15 of Set 11 | lom sak
# Processing Record 16 of Set 11 | pokhara
# Processing Record 17 of Set 11 | puerto ayacucho
# Processing Record 18 of Set 11 | hokitika
# Processing Record 19 of Set 11 | tuatapere
# Processing Record 20 of Set 11 | gat
# Processing Record 21 of Set 11 | yulara
# Processing Record 22 of Set 11 | mattru
# Processing Record 23 of Set 11 | ofunato
# Processing Record 24 of Set 11 | quatre cocos
# Processing Record 25 of Set 11 | mazagao
# Processing Record 26 of Set 11 | arvi
# Processing Record 27 of Set 11 | lloydminster
# Processing Record 28 of Set 11 | tokur
# Processing Record 29 of Set 11 | bamiantong
# Processing Record 30 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 11 | treinta y tres
# Processing Record 32 of Set 11 | novyy urengoy
# Processing Record 33 of Set 11 | zhuhai
# Processing Record 34 of Set 11 | oktyabrskiy
# Processing Record 35 of Set 11 | olafsvik
# Processing Record 36 of Set 11 | almunecar
# Processing Record 37 of Set 11 | quelimane
# Processing Record 38 of Set 11 | coffeyville
# Processing Record 39 of Set 11 | los llanos de aridane
# Processing Record 40 of Set 11 | zapadnaya dvina
# Processing Record 41 of Set 11 | nemuro
# Processing Record 42 of Set 11 | ixtacomitan
# Processing Record 43 of Set 11 | kurumkan
# Processing Record 44 of Set 11 | puerto escondido
# Processing Record 45 of Set 11 | tanout
# Processing Record 46 of Set 11 | kemin
# Processing Record 47 of Set 11 | vrangel
# Processing Record 48 of Set 11 | allanmyo
# City not found. Skipping...
# Processing Record 49 of Set 11 | grindavik
# Processing Record 50 of Set 11 | kati
# Processing Record 1 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 12 | santa rosalia
# Processing Record 3 of Set 12 | kiknur
# Processing Record 4 of Set 12 | kontagora
# Processing Record 5 of Set 12 | komsomolskiy
# Processing Record 6 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 12 | ippy
# Processing Record 8 of Set 12 | young
# Processing Record 9 of Set 12 | mecca
# Processing Record 10 of Set 12 | yar-sale
# Processing Record 11 of Set 12 | saint-augustin
# Processing Record 12 of Set 12 | kyabram
# Processing Record 13 of Set 12 | trinidad
# Processing Record 14 of Set 12 | tual
# Processing Record 15 of Set 12 | banjar
# Processing Record 16 of Set 12 | swift current
# Processing Record 17 of Set 12 | tahoua
# Processing Record 18 of Set 12 | mingoyo
# Processing Record 19 of Set 12 | salinas
# Processing Record 20 of Set 12 | camana
# Processing Record 21 of Set 12 | xam nua
# Processing Record 22 of Set 12 | whitehorse
# Processing Record 23 of Set 12 | barinas
# Processing Record 24 of Set 12 | luanda
# Processing Record 25 of Set 12 | hervey bay
# Processing Record 26 of Set 12 | rovaniemi
# Processing Record 27 of Set 12 | grimari
# City not found. Skipping...
# Processing Record 28 of Set 12 | alugan
# Processing Record 29 of Set 12 | mnogovershinnyy
# Processing Record 30 of Set 12 | ust-uda
# Processing Record 31 of Set 12 | tungor
# Processing Record 32 of Set 12 | palmares do sul
# Processing Record 33 of Set 12 | winchester
# Processing Record 34 of Set 12 | cedar city
# Processing Record 35 of Set 12 | yamada
# Processing Record 36 of Set 12 | killybegs
# Processing Record 37 of Set 12 | krasnyy tekstilshchik
# City not found. Skipping...
# Processing Record 38 of Set 12 | lodja
# Processing Record 39 of Set 12 | muskogee
# Processing Record 40 of Set 12 | saint-ambroise
# Processing Record 41 of Set 12 | tiksi
# Processing Record 42 of Set 12 | tuam
# Processing Record 43 of Set 12 | rawson
# Processing Record 44 of Set 12 | altay
# Processing Record 45 of Set 12 | araouane
# Processing Record 46 of Set 12 | east london
# Processing Record 47 of Set 12 | kastamonu
# Processing Record 48 of Set 12 | champerico
# Processing Record 49 of Set 12 | khon buri
# Processing Record 50 of Set 12 | waingapu
# Processing Record 1 of Set 13 | sayyan
# Processing Record 2 of Set 13 | dawlatabad
# Processing Record 3 of Set 13 | manali
# Processing Record 4 of Set 13 | kuandian
# Processing Record 5 of Set 13 | enshi
# Processing Record 6 of Set 13 | ust-kulom
# Processing Record 7 of Set 13 | ewo
# Processing Record 8 of Set 13 | bambanglipuro
# Processing Record 9 of Set 13 | kisangani
# Processing Record 10 of Set 13 | surt
# Processing Record 11 of Set 13 | hambantota
# Processing Record 12 of Set 13 | obo
# Processing Record 13 of Set 13 | bonfim
# Processing Record 14 of Set 13 | mishkino
# Processing Record 15 of Set 13 | belaya gora
# Processing Record 16 of Set 13 | faanui
# Processing Record 17 of Set 13 | salihorsk
# Processing Record 18 of Set 13 | santa rosa
# Processing Record 19 of Set 13 | lugovskoy
# Processing Record 20 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 13 | sistranda
# Processing Record 22 of Set 13 | isiro
# Processing Record 23 of Set 13 | carmen
# Processing Record 24 of Set 13 | arkhara
# Processing Record 25 of Set 13 | mingshui
# Processing Record 26 of Set 13 | luwuk
# Processing Record 27 of Set 13 | katete
# Processing Record 28 of Set 13 | mufulira
# Processing Record 29 of Set 13 | sept-iles
# Processing Record 30 of Set 13 | kon tum
# Processing Record 31 of Set 13 | mogadishu
# Processing Record 32 of Set 13 | hessisch oldendorf
# Processing Record 33 of Set 13 | mto wa mbu
# Processing Record 34 of Set 13 | villamontes
# Processing Record 35 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 13 | bandar
# Processing Record 37 of Set 13 | qasigiannguit
# Processing Record 38 of Set 13 | scarborough
# Processing Record 39 of Set 13 | sakakah
# Processing Record 40 of Set 13 | tautira
# Processing Record 41 of Set 13 | nyzhnya duvanka
# Processing Record 42 of Set 13 | tateyama
# Processing Record 43 of Set 13 | la sarre
# Processing Record 44 of Set 13 | vestmanna
# Processing Record 45 of Set 13 | vozhega
# Processing Record 46 of Set 13 | abalak
# Processing Record 47 of Set 13 | bintulu
# Processing Record 48 of Set 13 | mozarlandia
# Processing Record 49 of Set 13 | pavlodar
# Processing Record 50 of Set 13 | twentynine palms
# Processing Record 1 of Set 14 | gouyave
# Processing Record 2 of Set 14 | ghanzi
# Processing Record 3 of Set 14 | tynda
# Processing Record 4 of Set 14 | iwaki
# Processing Record 5 of Set 14 | douglas
# Processing Record 6 of Set 14 | znamenskoye
# Processing Record 7 of Set 14 | meadow lake
# Processing Record 8 of Set 14 | abaete
# Processing Record 9 of Set 14 | tura
# Processing Record 10 of Set 14 | teguldet
# Processing Record 11 of Set 14 | ifakara
# Processing Record 12 of Set 14 | harper
# Processing Record 13 of Set 14 | muros
# Processing Record 14 of Set 14 | tuy hoa
# Processing Record 15 of Set 14 | miranda
# Processing Record 16 of Set 14 | viedma
# Processing Record 17 of Set 14 | makakilo city
# Processing Record 18 of Set 14 | potchefstroom
# Processing Record 19 of Set 14 | teguise
# Processing Record 20 of Set 14 | pergamino
# Processing Record 21 of Set 14 | natalio
# Processing Record 22 of Set 14 | moose factory
# Processing Record 23 of Set 14 | teya
# Processing Record 24 of Set 14 | vorontsovka
# Processing Record 25 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 14 | cacak
# Processing Record 27 of Set 14 | jalingo
# Processing Record 28 of Set 14 | timra
# Processing Record 29 of Set 14 | corralillo
# Processing Record 30 of Set 14 | lingao
# Processing Record 31 of Set 14 | jambi
# Processing Record 32 of Set 14 | oranjestad
# Processing Record 33 of Set 14 | sambava
# Processing Record 34 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 35 of Set 14 | progreso
# Processing Record 36 of Set 14 | tpig
# Processing Record 37 of Set 14 | djambala
# Processing Record 38 of Set 14 | tadine
# Processing Record 39 of Set 14 | samarai
# Processing Record 40 of Set 14 | mateus leme
# Processing Record 41 of Set 14 | beidao
# Processing Record 42 of Set 14 | lagos
# Processing Record 43 of Set 14 | college
# Processing Record 44 of Set 14 | prince rupert
# Processing Record 45 of Set 14 | rocha
# Processing Record 46 of Set 14 | lahat
# Processing Record 47 of Set 14 | port keats
# Processing Record 48 of Set 14 | el guamo
# Processing Record 49 of Set 14 | haines junction
# Processing Record 50 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 1 of Set 15 | zyryanskoye
# Processing Record 2 of Set 15 | poya
# Processing Record 3 of Set 15 | cancun
# Processing Record 4 of Set 15 | newport
# Processing Record 5 of Set 15 | vaitape
# Processing Record 6 of Set 15 | betanzos
# Processing Record 7 of Set 15 | broome
# Processing Record 8 of Set 15 | lishu
# Processing Record 9 of Set 15 | lapeer
# Processing Record 10 of Set 15 | sibolga
# Processing Record 11 of Set 15 | ende
# Processing Record 12 of Set 15 | piacabucu
# Processing Record 13 of Set 15 | pingliang
# Processing Record 14 of Set 15 | leusden
# Processing Record 15 of Set 15 | bronnoysund
# Processing Record 16 of Set 15 | pathein
# Processing Record 17 of Set 15 | camacha
# Processing Record 18 of Set 15 | bosaso
# Processing Record 19 of Set 15 | bacungan
# Processing Record 20 of Set 15 | havelock
# Processing Record 21 of Set 15 | takoradi
# Processing Record 22 of Set 15 | banda aceh
# Processing Record 23 of Set 15 | raahe
# Processing Record 24 of Set 15 | jamame
# Processing Record 25 of Set 15 | los algarrobos
# Processing Record 26 of Set 15 | wattegama
# Processing Record 27 of Set 15 | ilhabela
# Processing Record 28 of Set 15 | iquique
# Processing Record 29 of Set 15 | altamont
# Processing Record 30 of Set 15 | lata
# Processing Record 31 of Set 15 | buala
# Processing Record 32 of Set 15 | yarada
# Processing Record 33 of Set 15 | lima
# Processing Record 34 of Set 15 | changde
# Processing Record 35 of Set 15 | aylmer
# Processing Record 36 of Set 15 | darhan
# Processing Record 37 of Set 15 | hanmer springs
# Processing Record 38 of Set 15 | fort nelson
# Processing Record 39 of Set 15 | jalu
# Processing Record 40 of Set 15 | la ronge
# Processing Record 41 of Set 15 | ji-parana
# City not found. Skipping...
# Processing Record 42 of Set 15 | port hedland
# Processing Record 43 of Set 15 | richards bay
# Processing Record 44 of Set 15 | domoni
# Processing Record 45 of Set 15 | alihe
# Processing Record 46 of Set 15 | lagoa
# Processing Record 47 of Set 15 | tecpan
# Processing Record 48 of Set 15 | turayf
# Processing Record 49 of Set 15 | puerto cabello
# Processing Record 50 of Set 15 | pozhva
# Processing Record 1 of Set 16 | doctor juan leon mallorquin
# Processing Record 2 of Set 16 | pallapatti
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 692

# %%
#create dataframe
city_data_df = pd.DataFrame(city_data)

#view dataframe
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Plotnikovo      RU  55.0247   85.9436     50.34        44
# 1                 Vaini      TO -21.2000 -175.2000     71.76        94
# 2              Hermanus      ZA -34.4187   19.2345     66.79        70
# 3                Torbay      CA  47.6666  -52.7314     43.57        87
# 4        Port Elizabeth      ZA -33.9180   25.5701     68.09        72
# 5                   Sur      OM  22.5667   59.5289     95.27        41
# 6  Vila Franca Do Campo      PT  37.7167  -25.4333     70.20        87
# 7                Castro      BR -24.7911  -50.0119     47.53        96
# 8              Kedrovyy      RU  56.1667   91.8167     41.41        87
# 9             Munchberg      DE  50.2000   11.7833     69.67        81
#
#    Cloudiness  Wind Speed Current Description
# 0          94       10.20     overcast clouds
# 1          20        3.44          few clouds
# 2          67        7.58       broken clouds
# 3          92       14.00     overcast clouds
# 4           0       17.27           clear sky
# 5          25       12.97    scattered clouds
# 6         100        9.44     overcast clouds
# 7          42        9.01    scattered clouds
# 8          99        4.00          light rain
# 9          74        4.00       broken clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
